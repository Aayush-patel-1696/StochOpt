# %%
import cvxpy as cp
import numpy as np
from itertools import product

# %%
shipping_cost = np.array([[1,3,2],[3,2,2]]).reshape(2,3)
all_demand = np.array([[100,150,120],[120,180,150],[150,200,180]]).reshape(3,3)
selling_price = np.array([[16,16]]).reshape(2,1)
produce = np.array([100,200]).reshape(2,1)
production_cost = np.array([11,10]).reshape(2,1)

# %%
senario = np.array([[100,120,150],
       [150,180,200],[120,150,180]])
senario_comb = []
index = np.arange(0,3)
index_permute = product(index,repeat=3)
for i in index_permute:
    temp_array =[]
    for j in range(0,3):
        temp_array.append(float(senario[j,:][i[j]]))
    senario_comb.append(temp_array)
all_demand = np.array(senario_comb).reshape(27,3)

# %%
def solve_second_stage_problem(produce,all_demand):

    duals = []
    vs = []

    for demand in all_demand:
        
        sell = cp.Variable(shape=(2,3))
        salvage = cp.Variable(shape=(2,1))

        objective = cp.Minimize(-16*cp.sum(sell,keepdims=True) + cp.trace(((shipping_cost@(sell.T)))))
        constraints = [cp.sum(sell,axis=1,keepdims=True) +salvage <= produce,cp.sum(sell,axis=0,keepdims=True) <= demand.reshape(1,-1), sell>= np.zeros_like(sell),salvage>= np.zeros_like(salvage)]

        problem = cp.Problem(objective, constraints)
        problem.solve()

        dual_value = problem.constraints[0].dual_value

        duals.append(dual_value)
        vs.append(problem.value)
        
    return np.array(duals).reshape(-1,2),np.array(vs).reshape(-1,1)

# %%
duals,vs = solve_second_stage_problem(produce,all_demand)

# %%
senario = 3
senario_prob = (1/senario)*(np.ones_like(all_demand[:,0])).reshape(-1,1)

# %%
g_ks_temp = (-senario_prob.T@duals).T
alpha_ks_temp = senario_prob.T@vs - g_ks_temp.T@produce

# %%
def solve_first_stage_problem(produce,g_ks,alpha_ks,senario_prob): 

    size = 2
    production_cost = np.array([11,10]).reshape(2,1)

    produce  = cp.Variable(shape=(2,1))
    produce_limit = np.array([300,300]).reshape(2,1)

    v = cp.Variable(shape=(len(senario_prob),1))

    constraints = []
    for i in range(0,len(g_ks)):
        for j in range(0,len(g_ks[i])):
            constraints.append(np.array([g_ks[i][j]])@produce+np.array([alpha_ks[i][j]])<=v[j])

    constraints.extend([produce>=0,v>=-1000000,produce<=produce_limit])

    objective = cp.Minimize(production_cost.T@produce + senario_prob.T@v)

    problem = cp.Problem(objective, constraints)
    problem.solve()

    print(problem.value)

    return produce.value, v.value

# %%
# produce = np.array([3,3,3]).reshape(-1,1)
limit = -100000

g_ks = []
alpha_ks = []

senario = 27
senario_prob = (1/senario)*(np.ones_like(all_demand[:,0])).reshape(-1,1)

for i in range(0,300):
    duals,qs = solve_second_stage_problem(produce,all_demand)

    gks_batch = []
    alpha_ks_batch = []

    for i in range(0,senario):
# [[120.00000194]
#  [300.00000004]]
# -1609.9999850502754
# [[120.00000185]
#  [300.00000004]]
# -1609.9999860935068
# [[120.00000147]
#  [300.00000001]]
# -1609.999986369835
# [[120.00000153]
#  [300.00000002]]
# -1609.9999866504795
# [[120.00000132]
#  [300.00000001]]
# -1609.9999855986662
# [[120.00000153]
#  [300.00000003]]
# -1609.9999867561837
# [[120.00000196]
#  [300.00000004]]
# -1609.9999867249544
# [[120.0000013 ]
#  [300.00000001]]
# -1609.9999834953196
# [[120.00000117]
#  [300.00000004]]
# -1609.9999860845246
# [[120.00000158]
#  [300.00000004]]
# -1609.999985543277
# [[120.00000197]
#  [300.00000003]]
# -1609.9999814653129
# [[120.00000146]
#  [300.00000005]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 23
#      20 g_ks.append(gks_batch)
#      21 alpha_ks.append(alpha_ks_batch)
# ---> 23 produce,limit= solve_first_stage_problem(produce,g_ks,alpha_ks,senario_prob)
#      24 print(produce)
#      26 # print(limit)
#
# Cell In[16], line 14, in solve_first_stage_problem(produce, g_ks, alpha_ks, senario_prob)
#      12 for i in range(0,len(g_ks)):
#      13     for j in range(0,len(g_ks[i])):
# ---> 14         constraints.append(np.array([g_ks[i][j]])@produce+np.array([alpha_ks[i][j]])<=v[j])
#      16 constraints.extend([produce>=0,v>=-1000000,produce<=produce_limit])
#      18 objective = cp.Minimize(production_cost.T@produce + senario_prob.T@v)
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\expressions\expression.py:50, in _cast_other.<locals>.cast_op(self, other)
#      47 """A wrapped binary operator that can handle non-Expression arguments.
#      48 """
#      49 other = self.cast_to_const(other)
# ---> 50 return binary_op(self, other)
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\expressions\expression.py:759, in Expression.__le__(self, other)
#     755 @_cast_other
#     756 def __le__(self, other: ExpressionLike):
#     757     """Inequality : Creates an inequality constraint ``self <= other``.
#     758     """
# --> 759     return Inequality(self, other)
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\constraints\nonpos.py:182, in Inequality.__init__(self, lhs, rhs, constr_id)
#     181 def __init__(self, lhs, rhs, constr_id=None) -> None:
# --> 182     self._expr = lhs - rhs
#     183     if self._expr.is_complex():
#     184         raise ValueError("Inequality constraints cannot be complex.")
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\expressions\expression.py:50, in _cast_other.<locals>.cast_op(self, other)
#      47 """A wrapped binary operator that can handle non-Expression arguments.
#      48 """
#      49 other = self.cast_to_const(other)
# ---> 50 return binary_op(self, other)
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\expressions\expression.py:613, in Expression.__sub__(self, other)
#     609 @_cast_other
#     610 def __sub__(self, other: ExpressionLike) -> "Expression":
#     611     """Expression : The difference of two expressions.
#     612     """
# --> 613     return self + -other
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\expressions\expression.py:718, in Expression.__neg__(self)
#     715 def __neg__(self):
#     716     """Expression : The negation of the expression.
#     717     """
# --> 718     return cvxtypes.neg_expr()(self)
#
# File c:\Users\aayus\Documents\GitHub\StochOpt\.venv\lib\site-packages\cvxpy\expressions\cvxtypes.py:91, in neg_expr()
#      90 def neg_expr():
# ---> 91     from cvxpy.atoms.affine import unary_operators
#      92     return unary_operators.NegExpression
#
# File <frozen importlib._bootstrap>:1064, in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:
